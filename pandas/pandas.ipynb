# %% [markdown]
# ## Pandasa giriş

# %%
import pandas as pd
import numpy as np

# %%
#seriler tek boyutludur
s = pd.Series([10,20,30,40],index = ["a","b","c","d"])
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# dataframe iki boyutludur
data = {
    "isim": ["ali","ayşe","mehmet"],
    "yas": [25,30,22],
    "sehir": ["istanbul","ankara","izmir"]
}
df = pd.DataFrame(data)
df
# Out:
#      isim  yas     sehir
# 0     ali   25  istanbul
# 1    ayşe   30    ankara
# 2  mehmet   22     izmir

# %%
print(f"Şekil (satır,sütün): {df.shape}")
print(f"Sütün isimleri: {df.columns}")
print(f"İndeksler: {df.index}")
print(f"veri tipi: {df.dtypes}")
# Out:
# Şekil (satır,sütün): (3, 3)
# Sütün isimleri: Index(['isim', 'yas', 'sehir'], dtype='object')
# İndeksler: RangeIndex(start=0, stop=3, step=1)
# veri tipi: isim     object
# yas       int64
# sehir    object
# dtype: object

# %% [markdown]
# ## Pandas Seriler

# %%
s1 = pd.Series([10,20,30,40]) #listeden seri oluşturma
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s2 = pd.Series([10,20,30,40],index=["a","b","c","d"])
s2
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data = {"Ali": 55, "Ayşe":45, "Mehmet":25}
s3 = pd.Series(data)
s3
# Out:
# Ali       55
# Ayşe      45
# Mehmet    25
# dtype: int64

# %%
s = pd.Series([10,20,30,40],index=["a","b","c","d"])
print(f"Değerler: {s.values}")
print(f"İndeksler: {s.index}")
print(f"Veri Tipi: {s.dtype}")
print(f"Boyut: {s.shape}")
# Out:
# Değerler: [10 20 30 40]
# İndeksler: Index(['a', 'b', 'c', 'd'], dtype='object')
# Veri Tipi: int64
# Boyut: (4,)

# %%
print(s["b"])
print(s["a":"c"])
print(s[0:2])
# Out:
# 20
# a    10
# b    20
# c    30
# dtype: int64
# a    10
# b    20
# dtype: int64

# %%
print(f"Toplam: {s.sum()}")
# Out:
# Toplam: 100

# %%
s = pd.Series([10,20,30,30,30,50,50])
print(s.unique())
print(s.value_counts())
# Out:
# [10 20 30 50]
# 30    3
# 50    2
# 20    1
# 10    1
# Name: count, dtype: int64

# %% [markdown]
# ## Pandas Dataframe

# %%
data = {
    "isim": ["Ali","Ayşe","Mehmet"],
    "yas": [25,30,22],
    "sehir": ["İstanbul","Ankara","İzmir"]
}
df = pd.DataFrame(data)
df
# Out:
#      isim  yas     sehir
# 0     Ali   25  İstanbul
# 1    Ayşe   30    Ankara
# 2  Mehmet   22     İzmir

# %%
arr = np.array([[1,"Ali",25],[2,"Ayşe",30],[3,"Mehmet",22]])
df = pd.DataFrame(arr,columns=["id","isim","yas"])
df
# Out:
#   id    isim yas
# 0  1     Ali  25
# 1  2    Ayşe  30
# 2  3  Mehmet  22

# %%
# satır ve sütün seçimleri

print(df["yas"])
print(df.loc[:,"yas"])
# Out:
# 0    25
# 1    30
# 2    22
# Name: yas, dtype: object
# 0    25
# 1    30
# 2    22
# Name: yas, dtype: object

# %%
print(df[["isim","yas"]])
print(df.loc[:,["isim","yas"]])
# Out:
#      isim yas
# 0     Ali  25
# 1    Ayşe  30
# 2  Mehmet  22
#      isim yas
# 0     Ali  25
# 1    Ayşe  30
# 2  Mehmet  22

# %%
#sütün ekleme ve sütün silme
df["puan"] = [80,90,85]
df
# Out:
#   id    isim yas  puan
# 0  1     Ali  25    80
# 1  2    Ayşe  30    90
# 2  3  Mehmet  22    85

# %%
df.drop("yas",axis=1,inplace=True) #axis = 1 -> sütün sil demek
df
# Out:
#   id    isim  puan
# 0  1     Ali    80
# 1  2    Ayşe    90
# 2  3  Mehmet    85

# %% [markdown]
# ## Veri Kaydetme ve Okuma

# %%
data = {
    "isim": ["Ali","Ayşe","Mehmet"],
    "yas": [25,30,22],
    "sehir": ["İstanbul","Ankara","İzmir"]
}
df = pd.DataFrame(data)
# kaydet
df.to_csv("ogrenciler.csv",index=False)
df.to_excel("ogrenciler.xlsx",index=False)
df.to_json("ogrenciler.json",orient="records",lines=True)

# %%
#tekrar oku
df1 = pd.read_csv("ogrenciler.csv")
df2 = pd.read_excel("ogrenciler.xlsx")
df3 = pd.read_json("ogrenciler.json",lines=True)
# Out:
#      isim  yas     sehir
# 0     Ali   25  İstanbul
# 1    Ayşe   30    Ankara
# 2  Mehmet   22     İzmir

# %% [markdown]
# ## Veri inceleme ve özetleme

# %%
# ilk ve son satırlara bakmak
data = {
    "isim":["ali","ayşe","mehmet","zeynep","burak"],
    "yas":[25,30,22,28,27],
    "not":[80,90,75,95,85]
}
df = pd.DataFrame(data)
print(df.head(3)) #ilk x satır
print(df.tail(3)) #son x satır
# Out:
#      isim  yas  not
# 2  mehmet   22   75
# 3  zeynep   28   95
# 4   burak   27   85

# %%
# genel bilgiler
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.info())
# Out:
# (5, 3)
# Index(['isim', 'yas', 'not'], dtype='object')
# isim    object
# yas      int64
# not      int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    5 non-null      object
#  1   yas     5 non-null      int64
#  2   not     5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None

# %%
#temel istatiksel analiz
print(df.describe())
# Out:
#             yas        not
# count   5.00000   5.000000
# mean   26.40000  85.000000
# std     3.04959   7.905694
# min    22.00000  75.000000
# 25%    25.00000  80.000000
# 50%    27.00000  85.000000
# 75%    28.00000  90.000000
# max    30.00000  95.000000

# %%
print(df.isnull()) #eksik değer var mı
print(df.isnull().sum()) #her sütundaki eksik değer sayısı
# Out:
#     isim    yas    not
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# isim    0
# yas     0
# not     0
# dtype: int64

# %%
df.loc[2,"not"] = None
print(df.isnull())
print(df.isnull().sum())
# Out:
#     isim    yas    not
# 0  False  False  False
# 1  False  False  False
# 2  False  False   True
# 3  False  False  False
# 4  False  False  False
# isim    0
# yas     0
# not     1
# dtype: int64

# %%
#benzersiz değerler
print(df["yas"].unique())
print(df["yas"].nunique())
print(df.value_counts())
# Out:
# [25 30 22 28 27]
# 5
# isim    yas  not
# ali     25   80.0    1
# ayşe    30   90.0    1
# burak   27   85.0    1
# zeynep  28   95.0    1
# Name: count, dtype: int64

# %%
df["yas"].value_counts()
# Out:
# yas
# 25    1
# 30    1
# 22    1
# 28    1
# 27    1
# Name: count, dtype: int64

# %% [markdown]
# ## Veri Seçme ve Filtreleme

# %%
data = {
    "isim":["ali","ayşe","mehmet","zeynep","burak"],
    "yas":[25,30,22,28,27],
    "not":[80,90,75,95,85]
}
df = pd.DataFrame(data)
print(f"Notu 85 den büyük olanlar: \n {df[df["not"] > 85]}")
print(f"Yaşı 25 olanlar: \n {df[df["yas"] == 25]}")
# Out:
# Notu 85 den büyük olanlar:
#       isim  yas  not
# 1    ayşe   30   90
# 3  zeynep   28   95
# Yaşı 25 olanlar:
#    isim  yas  not
# 0  ali   25   80

# %%
#boolean maskeler
mask = df["not"] > 85
df[mask]
# Out:
#      isim  yas  not
# 1    ayşe   30   90
# 3  zeynep   28   95

# %%
#çoklu koşullar
# 50 <= not <= 90
print(f"Orta başarı: \n {df[(df["not"] >= 50) & (df["not"] <= 90)]}")
# Out:
# Orta başarı:
#       isim  yas  not
# 0     ali   25   80
# 1    ayşe   30   90
# 2  mehmet   22   75
# 4   burak   27   85

# %% [markdown]
# ## Veri Temizleme

# %%
data = {
    "isim":["ali","ayşe","mehmet","zeynep","burak"],
    "yas":[25,None,22,None,27],
    "not":[80,90,None,95,85]
}
df = pd.DataFrame(data)
df.isnull()
# Out:
#     isim    yas    not
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False   True  False
# 4  False  False  False

# %%
df.dropna() #silme
# Out:
#     isim   yas   not
# 0    ali  25.0  80.0
# 4  burak  27.0  85.0

# %%
df.fillna(0) #eksik veri doldurma
# Out:
#      isim   yas   not
# 0     ali  25.0  80.0
# 1    ayşe   0.0  90.0
# 2  mehmet  22.0   0.0
# 3  zeynep   0.0  95.0
# 4   burak  27.0  85.0

# %%
df["yas"].fillna(df["yas"].mean())
# Out:
# 0    25.000000
# 1    24.666667
# 2    22.000000
# 3    24.666667
# 4    27.000000
# Name: yas, dtype: float64

# %%
#yinelenen veriler
data = {
    "isim":["ali","ayşe","ali","zeynep","burak"],
    "yas":[25,None,25,None,27],
    "not":[80,90,80,None,85]
}
df = pd.DataFrame(data)
df.duplicated() #yinelenen değer kontrolu, satır satır bakıyor yani her şeyi aynı mı diye
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#      isim   yas   not
# 0     ali  25.0  80.0
# 1    ayşe   NaN  90.0
# 3  zeynep   NaN   NaN
# 4   burak  27.0  85.0

# %%
#değer değiştirme
df.replace({"ali":"ali_isim"})
# Out:
#        isim   yas   not
# 0  ali_isim  25.0  80.0
# 1      ayşe   NaN  90.0
# 2  ali_isim  25.0  80.0
# 3    zeynep   NaN   NaN
# 4     burak  27.0  85.0

# %%
data = {
    "isim":[" ali","Ayse","mehmet","zeYnep","burak"],
    "yas":[25,21,22,23,27],
    "not":[80,90,75,95,85]
}
df = pd.DataFrame(data)
df["isim"] = df["isim"].str.lower() #küçük harf yap
df["isim"] = df["isim"].str.strip() #boşluktan kurtul
df
# Out:
#      isim  yas  not
# 0     ali   25   80
# 1    ayse   21   90
# 2  mehmet   22   75
# 3  zeynep   23   95
# 4   burak   27   85

# %% [markdown]
# ## Veri Dönüştürme

# %%
data = {
    "isim":["ali","ayşe","mehmet","zeynep","burak"],
    "yas":[25,30,22,28,27],
    "not":[80,90,75,95,85]
}
df = pd.DataFrame(data)
df = df.sort_values(by = "not",ascending = False) #notlara göre sıralama

# %%
#yeniden indeksleme
df = df.reindex([0,1,2,3,4])
df
# Out:
#      isim  yas  not
# 0     ali   25   80
# 1    ayşe   30   90
# 2  mehmet   22   75
# 3  zeynep   28   95
# 4   burak   27   85

# %%
#tip dönüştürme
df.info()
df["not"] = df["not"].astype(float)
df["yas"] = df["yas"].astype(str)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    5 non-null      object
#  1   yas     5 non-null      int64
#  2   not     5 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 160.0+ bytes
#      isim yas   not
# 0     ali  25  80.0
# 1    ayşe  30  90.0
# 2  mehmet  22  75.0
# 3  zeynep  28  95.0
# 4   burak  27  85.0

# %%
#kategorik veri ekle
df["sehir"] = ["ankara","izmir","antalya","konya","istanbul"]
df["sehir"] = df["sehir"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    5 non-null      object
#  1   yas     5 non-null      object
#  2   not     5 non-null      float64
#  3   sehir   5 non-null      category
# dtypes: category(1), float64(1), object(2)
# memory usage: 377.0+ bytes

# %% [markdown]
# ## Gruplama ve Özetleme

# %%
#temel gruplama
data = {
    "departman": ["IT","IT","HR","HR","Muhasebe","IT"],
    "personel" : ["ali","ayşe","mehmet","zeynep","burak","can"],
    "maaş" : [1222,1333,1444,1414,8666,1279]
    }
df = pd.DataFrame(data)
df.groupby("departman")["maaş"].mean()
# Out:
# departman
# HR          1429.0
# IT          1278.0
# Muhasebe    8666.0
# Name: maaş, dtype: float64

# %%
#toplama, ortalama ve sayma
df.groupby("departman")["maaş"].sum() #toplam maaş
# Out:
# departman
# HR          2858
# IT          3834
# Muhasebe    8666
# Name: maaş, dtype: int64

# %%
df.groupby("departman")["maaş"].count() #kişi sayısı
# Out:
# departman
# HR          2
# IT          3
# Muhasebe    1
# Name: maaş, dtype: int64

# %%
# birden fazla sütuna göre gruplama
data = {
    "departman": ["IT","IT","HR","HR","Muhasebe","IT"],
    "personel" : ["ali","ayşe","mehmet","zeynep","burak","can"],
    "sehir" : ["Ankara","İstanbul","Rize","Rize","İstanbul","Rize"],
    "maaş" : [1222,1333,1444,1414,8666,1279]
    }
df = pd.DataFrame(data)
df.groupby(["departman","sehir"])["maaş"].mean()
# Out:
# departman  sehir
# HR         Rize        1429.0
# IT         Ankara      1222.0
#            Rize        1279.0
#            İstanbul    1333.0
# Muhasebe   İstanbul    8666.0
# Name: maaş, dtype: float64

# %%
#agg()
df.groupby("departman")["maaş"].agg(["min","max","mean"])
# Out:
#             min   max    mean
# departman
# HR         1414  1444  1429.0
# IT         1222  1333  1278.0
# Muhasebe   8666  8666  8666.0

# %% [markdown]
# ## Birleştirme ve Bir Araya Getirme

# %%
#merge
df1 = pd.DataFrame({"id":[1,2,3],"isim":["Ali","Ayşe","Mehmet"]})
df2 = pd.DataFrame({"id":[1,2,4],"şehir":["Ankara","İstanbul","İzmir"]})
df_merge = pd.merge(df1,df2,on="id",how="inner") #ortak olan kayıtlar
df_merge
# Out:
#    id  isim     şehir
# 0   1   Ali    Ankara
# 1   2  Ayşe  İstanbul

# %%
df_merge = pd.merge(df1,df2,on="id",how="left") #soldaki veriseti için tüm kayıtlar
df_merge
# Out:
#    id    isim     şehir
# 0   1     Ali    Ankara
# 1   2    Ayşe  İstanbul
# 2   3  Mehmet       NaN

# %%
df_merge = pd.merge(df1,df2,on="id",how="right") #sağdaki veriseti için tüm kayıtlar
df_merge
# Out:
#    id  isim     şehir
# 0   1   Ali    Ankara
# 1   2  Ayşe  İstanbul
# 2   4   NaN     İzmir

# %%
#indeks bazlı birleştirme
df1 = pd.DataFrame({"isim":["Ali","Ayşe","Mehmet"]},index=["a","b","c"])
df2 = pd.DataFrame({"not": [85,90,75]},index=["a","b","d"])

pd.merge(df1,df2,left_index=True,right_index=True,how="outer") # her iki tarafın tüm kayıtları gelir
# Out:
#      isim   not
# a     Ali  85.0
# b    Ayşe  90.0
# c  Mehmet   NaN
# d     NaN  75.0
